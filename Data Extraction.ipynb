# %%
pip install snscrape
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
query = "(@PeterObi) until:2023-02-16 since:2022-06-17"
tweets = []
limit = 50000

for tweet in sntwitter.TwitterHashtagScraper(query).get_items():
    if len(tweets) ==limit:
        break
    else:
        tweets.append([tweet.date, tweet.url, tweet.user.username, tweet.sourceLabel, tweet.user.location, tweet.content, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount])
        
Peter = pd.DataFrame(tweets, columns=['Date', 'TweetURL', 'User', 'Source', 'Location', 'Tweet', 'Likes_Counts', 'Retweets_Count','Quote_Count','Reply_Count'])
Peter.to_csv('PeterObi.csv')

# %%
Peter.head(25000)
# Out:
#                            Date  \
# 0     2023-02-15 23:59:26+00:00
# 1     2023-02-15 23:59:24+00:00
# 2     2023-02-15 23:59:18+00:00
# 3     2023-02-15 23:59:04+00:00
# 4     2023-02-15 23:59:03+00:00
# ...                         ...
# 24995 2023-02-14 14:07:09+00:00
# 24996 2023-02-14 14:07:00+00:00
# 24997 2023-02-14 14:06:57+00:00
# 24998 2023-02-14 14:06:53+00:00
# 24999 2023-02-14 14:06:37+00:00
#
#                                                 TweetURL             User  \
# 0      https://twitter.com/Bigkingzz1/status/16260083...       Bigkingzz1
# 1      https://twitter.com/thedreamreaper/status/1626...   thedreamreaper
# 2      https://twitter.com/Delejackson4/status/162600...     Delejackson4
# 3      https://twitter.com/MvahanNico/status/16260082...       MvahanNico
# 4      https://twitter.com/DonatusChiekezi/status/162...  DonatusChiekezi
# ...                                                  ...              ...
# ...

# %%
query = "(@officialABAT) until:2023-02-16 since:2022-06-17"
tweets = []
limit = 50000

for tweet in sntwitter.TwitterHashtagScraper(query).get_items():
    if len(tweets) ==limit:
        break
    else:
        tweets.append([tweet.date, tweet.url, tweet.user.username, tweet.sourceLabel, tweet.user.location, tweet.content, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount])
        
Bola = pd.DataFrame(tweets, columns=['Date', 'TweetURL', 'User', 'Source', 'Location', 'Tweet', 'Likes_Counts', 'Retweets_Count','Quote_Count','Reply_Count'])
Bola.to_csv('Bolatinubu.csv')

# %%
 Bola.head(50000)
# Out:
#                            Date  \
# 0     2023-02-15 23:59:30+00:00
# 1     2023-02-15 23:59:18+00:00
# 2     2023-02-15 23:59:13+00:00
# 3     2023-02-15 23:59:03+00:00
# 4     2023-02-15 23:58:40+00:00
# ...                         ...
# 49995 2023-02-09 08:26:52+00:00
# 49996 2023-02-09 08:26:44+00:00
# 49997 2023-02-09 08:26:20+00:00
# 49998 2023-02-09 08:26:11+00:00
# 49999 2023-02-09 08:25:32+00:00
#
#                                                 TweetURL             User  \
# 0      https://twitter.com/Bundlehofjoy/status/162600...     Bundlehofjoy
# 1      https://twitter.com/Delejackson4/status/162600...     Delejackson4
# 2      https://twitter.com/myikel203/status/162600826...        myikel203
# 3      https://twitter.com/DonatusChiekezi/status/162...  DonatusChiekezi
# 4      https://twitter.com/Holyygraiil/status/1626008...      Holyygraiil
# ...                                                  ...              ...
# ...

# %%
query = "(@Atiku) until:2023-02-16 since:2022-06-17"
tweets = []
limit = 50000

for tweet in sntwitter.TwitterHashtagScraper(query).get_items():
    if len(tweets) ==limit:
        break
    else:
        tweets.append([tweet.date, tweet.url, tweet.user.username, tweet.sourceLabel, tweet.user.location, tweet.content, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount])
        
Atiku = pd.DataFrame(tweets, columns=['Date', 'TweetURL', 'User', 'Source', 'Location', 'Tweet', 'Likes_Counts', 'Retweets_Count','Quote_Count','Reply_Count'])
Atiku.to_csv('Atikuabu.csv')

# %%
 Atiku.head(50000)
# Out:
#                            Date  \
# 0     2023-02-15 23:58:52+00:00
# 1     2023-02-15 23:57:23+00:00
# 2     2023-02-15 23:56:54+00:00
# 3     2023-02-15 23:56:52+00:00
# 4     2023-02-15 23:55:27+00:00
# ...                         ...
# 49995 2023-01-31 12:16:00+00:00
# 49996 2023-01-31 12:15:55+00:00
# 49997 2023-01-31 12:15:54+00:00
# 49998 2023-01-31 12:15:54+00:00
# 49999 2023-01-31 12:15:51+00:00
#
#                                                 TweetURL            User  \
# 0      https://twitter.com/KingDGen_N/status/16260081...      KingDGen_N
# 1      https://twitter.com/Invincible7god/status/1626...  Invincible7god
# 2      https://twitter.com/Mazi_EbubeDike/status/1626...  Mazi_EbubeDike
# 3      https://twitter.com/mahbeel_A/status/162600766...       mahbeel_A
# 4      https://twitter.com/jadonnnn12/status/16260073...      jadonnnn12
# ...                                                  ...             ...
# ...
